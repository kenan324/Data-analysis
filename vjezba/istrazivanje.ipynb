# %%
#Istraživanje programa

##Pokušajte pronaći odgovore na sljedeća pitanja.

Pokušajte pronaći odgovore na sljedeća pitanja. Eksperimentirajte s nekim izmjenama code-a i ponovno pokrenite program kako biste vidjeli kakav učinak promjene imaju.

1. Što se događa ako igrač unese prazan niz za poruku?
2. Je li važno koji su znakovi koji nisu razmak u nizu bitmap varijable?
3. Što predstavlja varijabla i stvorena u retku 37?
4. Koja se greška događa ako izbrišete ili komentirate print() u retku 44?
# Out:
#   Cell In[12], line 5
#     Pokušajte pronaći odgovore na sljedeća pitanja. Eksperimentirajte s nekim izmjenama code-a i ponovno pokrenite program kako biste vidjeli kakav učinak promjene imaju.
#               ^
# SyntaxError: invalid syntax
